# %% [markdown]
# ## Loading the data

# %% [markdown]
# #### Imporing Libraries

# %%
import numpy as np
import pandas as pd

import warnings
warnings.simplefilter(action='ignore')

# %%
data = pd.read_csv('ratings.csv')
data.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
movie_titles_genre = pd.read_csv("movies.csv")
movie_titles_genre.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
data = data.merge(movie_titles_genre,on='movieId', how='left')
data.head(10)
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
# 5       1       70     3.0  964982400   From Dusk Till Dawn (1996)
# 6       1      101     5.0  964980868         Bottle Rocket (1996)
# 7       1      110     4.0  964982176            Braveheart (1995)
# 8       1      151     5.0  964984041               Rob Roy (1995)
# 9       1      157     5.0  964984100        Canadian Bacon (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller
# 5                Action|Comedy|Horror|Thriller
# 6               Adventure|Comedy|Crime|Romance
# 7                             Action|Drama|War
# 8                     Action|Drama|Romance|War
# 9                                   Comedy|War

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Average Rating

# %%
Average_ratings = pd.DataFrame(data.groupby('title')['rating'].mean())
Average_ratings.head(10)
# Out:
#                                            rating
# title
# '71 (2014)                               4.000000
# 'Hellboy': The Seeds of Creation (2004)  4.000000
# 'Round Midnight (1986)                   3.500000
# 'Salem's Lot (2004)                      5.000000
# 'Til There Was You (1997)                4.000000
# 'Tis the Season for Love (2015)          1.500000
# 'burbs, The (1989)                       3.176471
# 'night Mother (1986)                     3.000000
# (500) Days of Summer (2009)              3.666667
# *batteries not included (1987)           3.285714

# %% [markdown]
# ### Total Number Of Rating

# %% [markdown]
# ##### The rating of a movie is proportional to the total number of ratings it has. Therefore, we will also consider the total ratings cast for each movie.

# %%
Average_ratings['Total Ratings'] = pd.DataFrame(data.groupby('title')['rating'].count())
Average_ratings.head(10)
# Out:
#                                            rating  Total Ratings
# title
# '71 (2014)                               4.000000              1
# 'Hellboy': The Seeds of Creation (2004)  4.000000              1
# 'Round Midnight (1986)                   3.500000              2
# 'Salem's Lot (2004)                      5.000000              1
# 'Til There Was You (1997)                4.000000              2
# 'Tis the Season for Love (2015)          1.500000              1
# 'burbs, The (1989)                       3.176471             17
# 'night Mother (1986)                     3.000000              1
# (500) Days of Summer (2009)              3.666667             42
# *batteries not included (1987)           3.285714              7

# %% [markdown]
# ## Building The Recommender

# %% [markdown]
# ### Calculating The Correlation

# %% [markdown]
# ##### We will create a table where the rows are userIds and the columns represent the movies. The values of the matrix represent the rating for each movie by each user.

# %%
movie_user = data.pivot_table(index='userId',columns='title',values='rating')
movie_user.head(10)
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# 6              NaN                                      NaN
# 7              NaN                                      NaN
# 8              NaN                                      NaN
# 9              NaN                                      NaN
# 10             NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
# 6                          NaN                  NaN
# 7                          NaN                  NaN
# 8                          NaN                  NaN
# 9                          NaN                  NaN
# 10                         NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
# 7                             NaN                              NaN
# 8                             NaN                              NaN
# 9                             NaN                              NaN
# 10                            NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
# 6                      NaN                   NaN                          NaN
# 7                      NaN                   NaN                          NaN
# 8                      NaN                   NaN                          NaN
# 9                      NaN                   NaN                          NaN
# 10                     NaN                   NaN                          NaN
#
# title   *batteries not included (1987)  ...  Zulu (2013)  [REC] (2007)  \
# userId                                  ...
# 1                                  NaN  ...          NaN           NaN
# 2                                  NaN  ...          NaN           NaN
# 3                                  NaN  ...          NaN           NaN
# 4                                  NaN  ...          NaN           NaN
# 5                                  NaN  ...          NaN           NaN
# 6                                  NaN  ...          NaN           NaN
# 7                                  NaN  ...          NaN           NaN
# 8                                  NaN  ...          NaN           NaN
# 9                                  NaN  ...          NaN           NaN
# 10                                 NaN  ...          NaN           NaN
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5                 NaN                      NaN
# 6                 NaN                      NaN
# 7                 NaN                      NaN
# 8                 NaN                      NaN
# 9                 NaN                      NaN
# 10                NaN                      NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                   NaN         NaN                             NaN
# 2                   NaN         NaN                             NaN
# 3                   NaN         NaN                             NaN
# 4                   NaN         NaN                             NaN
# 5                   NaN         NaN                             NaN
# 6                   NaN         NaN                             NaN
# 7                   NaN         NaN                             NaN
# 8                   NaN         NaN                             NaN
# 9                   NaN         1.0                             NaN
# 10                  NaN         NaN                             NaN
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userId
# 1                         4.0                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4                         NaN                                        NaN
# 5                         NaN                                        NaN
# 6                         NaN                                        NaN
# 7                         NaN                                        NaN
# 8                         NaN                                        NaN
# 9                         NaN                                        NaN
# 10                        NaN                                        NaN
#
# [10 rows x 9719 columns]

# %% [markdown]
# ##### Now we need to select a movie to test our recommender system.

# %% [markdown]
# ###### Corrwith method computes the pairwise correlation between rows or columns of a DataFrame with rows or columns of Series or DataFrame.

# %%
correlations = movie_user.corrwith(movie_user['Seven (a.k.a. Se7en) (1995)'])
correlations.head()
# Out:
# title
# '71 (2014)                                NaN
# 'Hellboy': The Seeds of Creation (2004)   NaN
# 'Round Midnight (1986)                    NaN
# 'Salem's Lot (2004)                       NaN
# 'Til There Was You (1997)                 NaN
# dtype: float64

# %% [markdown]
# ##### Now we will remove all the empty values and merge the total ratings to the correlation table.

# %%
recommendation = pd.DataFrame(correlations,columns=['Correlation'])
recommendation.dropna(inplace=True)
recommendation = recommendation.join(Average_ratings['Total Ratings'])
recommendation.head()
# Out:
#                                    Correlation  Total Ratings
# title
# 'burbs, The (1989)                    0.175075             17
# (500) Days of Summer (2009)           0.088741             42
# 10 Cloverfield Lane (2016)           -0.107096             14
# 10 Things I Hate About You (1999)    -0.215209             54
# 10,000 BC (2008)                      0.403631             17

# %% [markdown]
# ### Testing The Recommendation System

# %% [markdown]
# ##### Let’s filter all the movies with a correlation value to Seven movie and with at least 100 ratings.

# %%
recc = recommendation[recommendation['Total Ratings']>100].sort_values('Correlation',ascending=False).reset_index()

# %% [markdown]
# ##### Let’s also merge the movies dataset for verifying the recommendations.

# %%
recc = recc.merge(movie_titles_genre,on='title', how='left')
recc.head(10)
# Out:
#                                                title  Correlation  \
# 0                        Seven (a.k.a. Se7en) (1995)     1.000000
# 1                           Good Will Hunting (1997)     0.514347
# 2                                  Fight Club (1999)     0.510702
# 3                              Reservoir Dogs (1992)     0.494351
# 4                         Saving Private Ryan (1998)     0.437833
# 5       Eternal Sunshine of the Spotless Mind (2004)     0.434593
# 6                                     Memento (2000)     0.424050
# 7  Lord of the Rings: The Return of the King, The...     0.420570
# 8                            Truman Show, The (1998)     0.418610
# 9                              Godfather, The (1972)     0.403199
#
#    Total Ratings  movieId                          genres
# 0            203       47                Mystery|Thriller
# 1            141     1704                   Drama|Romance
# 2            218     2959     Action|Crime|Drama|Thriller
# 3            131     1089          Crime|Mystery|Thriller
# 4            188     2028                Action|Drama|War
# 5            131     7361            Drama|Romance|Sci-Fi
# 6            159     4226                Mystery|Thriller
# 7            185     7153  Action|Adventure|Drama|Fantasy
# 8            125     1682             Comedy|Drama|Sci-Fi
# 9            192      858                     Crime|Drama

# %% [markdown]
# ##### We can see that the top recommendations are pretty good. The movie that has the highest/full correlation to Seven is Seven itself. The movies such as Good Will Hunting (1997), Fight Club (1999) and Reservoir Dogs (1992)  are the next top high correlation with Seven and recommended to watch if you liked Seven.
